# %% [markdown]
# 5 epochs

# %%
import matplotlib.pyplot as plt

# Metrics data for 5 epochs
metrics_5 = {
    'ResNet': {'accuracy': 0.8005},
    'AlexNet': {'accuracy': 0.6023},
    'VGG16': {'accuracy': 0.7034},
    'LeNet': {'accuracy': 0.5049}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_5['ResNet'].keys():
    plt.plot(models, [metrics_5[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_5[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Accuracy at 5 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 5 epochs
metrics_5 = {
    'ResNet': {'val_accuracy': 0.7531},
    'AlexNet': {'val_accuracy': 0.5846},
    'VGG16': {'val_accuracy': 0.6887},
    'LeNet': {'val_accuracy': 0.4821}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_5['ResNet'].keys():
    plt.plot(models, [metrics_5[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_5[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Accuracy at 5 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 5 epochs
metrics_5 = {
    'ResNet': {'loss': 0.6012},
    'AlexNet': {'loss': 1.0045},
    'VGG16': { 'loss': 0.8056},
    'LeNet': {'loss': 1.2011}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_5['ResNet'].keys():
    plt.plot(models, [metrics_5[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_5[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Loss at 5 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 5 epochs
metrics_5 = {
    'ResNet': {'val_loss': 0.7014},
    'AlexNet': { 'val_loss': 1.1032},
    'VGG16': { 'val_loss': 0.9011},
    'LeNet': { 'val_loss': 1.3014}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_5['ResNet'].keys():
    plt.plot(models, [metrics_5[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_5[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Loss at 5 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 5 epochs
metrics_5 = {
    'ResNet': {'accuracy': 0.8005, 'loss': 0.6012, 'val_accuracy': 0.7531, 'val_loss': 0.7014},
    'AlexNet': {'accuracy': 0.6023, 'loss': 1.0045, 'val_accuracy': 0.5846, 'val_loss': 1.1032},
    'VGG16': {'accuracy': 0.7034, 'loss': 0.8056, 'val_accuracy': 0.6887, 'val_loss': 0.9011},
    'LeNet': {'accuracy': 0.5049, 'loss': 1.2011, 'val_accuracy': 0.4821, 'val_loss': 1.3014}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_5['ResNet'].keys():
    plt.plot(models, [metrics_5[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_5[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Model Metrics at 5 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.legend(loc='upper left')
plt.grid(True)

plt.show()

# %% [markdown]
# 10 epochs

# %%
import matplotlib.pyplot as plt

# Metrics data for 10 epochs
metrics_10 = {
    'ResNet': {'accuracy': 0.8501},
    'AlexNet': {'accuracy': 0.6521},
    'VGG16': {'accuracy': 0.7533},
    'LeNet': {'accuracy': 0.5548}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_10['ResNet'].keys():
    plt.plot(models, [metrics_10[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_10[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Accuracy at 10 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 10 epochs
metrics_10 = {
    'ResNet': {'val_accuracy': 0.8012},
    'AlexNet': {'val_accuracy': 0.6345},
    'VGG16': {'val_accuracy': 0.7384},
    'LeNet': {'val_accuracy': 0.5320}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_10['ResNet'].keys():
    plt.plot(models, [metrics_10[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_10[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Accuracy at 10 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 10 epochs
metrics_10 = {
    'ResNet': {'loss': 0.4512},
    'AlexNet': {'loss': 0.9042},
    'VGG16': {'loss': 0.7053},
    'LeNet': {'loss': 1.1012}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_10['ResNet'].keys():
    plt.plot(models, [metrics_10[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_10[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Loss at 10 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 10 epochs
metrics_10 = {
    'ResNet': {'val_loss': 0.6014},
    'AlexNet': {'val_loss': 1.0031},
    'VGG16': {'val_loss': 0.8012},
    'LeNet': {'val_loss': 1.2013}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_10['ResNet'].keys():
    plt.plot(models, [metrics_10[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_10[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Loss at 10 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 10 epochs
metrics_10 = {
    'ResNet': {'accuracy': 0.8501, 'loss': 0.4512, 'val_accuracy': 0.8012, 'val_loss': 0.6014},
    'AlexNet': {'accuracy': 0.6521, 'loss': 0.9042, 'val_accuracy': 0.6345, 'val_loss': 1.0031},
    'VGG16': {'accuracy': 0.7533, 'loss': 0.7053, 'val_accuracy': 0.7384, 'val_loss': 0.8012},
    'LeNet': {'accuracy': 0.5548, 'loss': 1.1012, 'val_accuracy': 0.5320, 'val_loss': 1.2013}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_10['ResNet'].keys():
    plt.plot(models, [metrics_10[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_10[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Model Metrics at 10 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.legend(loc='upper left')
plt.grid(True)

plt.show()

# %% [markdown]
# 15 epochs

# %%
import matplotlib.pyplot as plt

# Metrics data for 15 epochs
metrics_15 = {
    'ResNet': {'accuracy': 0.8802},
    'AlexNet': {'accuracy': 0.7024},
    'VGG16': {'accuracy': 0.8031},
    'LeNet': {'accuracy': 0.6047}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_15['ResNet'].keys():
    plt.plot(models, [metrics_15[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_15[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Accuracy at 15 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 15 epochs
metrics_15 = {
    'ResNet': {'val_accuracy': 0.8503},
    'AlexNet': {'val_accuracy': 0.6844},
    'VGG16': {'val_accuracy': 0.7880},
    'LeNet': {'val_accuracy': 0.5819}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_15['ResNet'].keys():
    plt.plot(models, [metrics_15[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_15[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Accuracy at 15 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 15 epochs
metrics_15 = {
    'ResNet': {'loss': 0.3510},
    'AlexNet': {'loss': 0.8040},
    'VGG16': {'loss': 0.6050},
    'LeNet': {'loss': 1.0013}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_15['ResNet'].keys():
    plt.plot(models, [metrics_15[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_15[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Loss at 15 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 15 epochs
metrics_15 = {
    'ResNet': {'val_loss': 0.5013},
    'AlexNet': {'val_loss': 0.9030},
    'VGG16': {'val_loss': 0.7011},
    'LeNet': {'val_loss': 1.1012}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_15['ResNet'].keys():
    plt.plot(models, [metrics_15[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_15[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Loss at 15 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 15 epochs
metrics_15 = {
    'ResNet': {'accuracy': 0.8802, 'loss': 0.3510, 'val_accuracy': 0.8503, 'val_loss': 0.5013},
    'AlexNet': {'accuracy': 0.7024, 'loss': 0.8040, 'val_accuracy': 0.6844, 'val_loss': 0.9030},
    'VGG16': {'accuracy': 0.8031, 'loss': 0.6050, 'val_accuracy': 0.7880, 'val_loss': 0.7011},
    'LeNet': {'accuracy': 0.6047, 'loss': 1.0013, 'val_accuracy': 0.5819, 'val_loss': 1.1012}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_15['ResNet'].keys():
    plt.plot(models, [metrics_15[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_15[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Model Metrics at 15 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.legend(loc='upper left')
plt.grid(True)

plt.show()

# %% [markdown]
# 20 epochs

# %%
import matplotlib.pyplot as plt

# Metrics data for 20 epochs
metrics_20 = {
    'ResNet': {'accuracy': 0.9003},
    'AlexNet': {'accuracy': 0.7525},
    'VGG16': {'accuracy': 0.8528},
    'LeNet': {'accuracy': 0.6546}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_20['ResNet'].keys():
    plt.plot(models, [metrics_20[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_20[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Accuracy at 20 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 20 epochs
metrics_20 = {
    'ResNet': {'val_accuracy': 0.8704},
    'AlexNet': {'val_accuracy': 0.73430},
    'VGG16': {'val_accuracy': 0.8377},
    'LeNet': {'val_accuracy': 0.6318}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_20['ResNet'].keys():
    plt.plot(models, [metrics_20[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_20[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Accuracy at 20 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 20 epochs
metrics_20 = {
    'ResNet': {'loss': 0.2508},
    'AlexNet': {'loss': 0.7038},
    'VGG16': {'loss': 0.5049},
    'LeNet': {'loss': 0.9014}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_20['ResNet'].keys():
    plt.plot(models, [metrics_20[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_20[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Training Loss at 20 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 20 epochs
metrics_20 = {
    'ResNet': {'val_loss': 0.4012},
    'AlexNet': {'val_loss': 0.8030},
    'VGG16': {'val_loss': 0.6011},
    'LeNet': {'val_loss': 1.0011}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_20['ResNet'].keys():
    plt.plot(models, [metrics_20[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_20[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Validation Loss at 20 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data for 20 epochs
metrics_20 = {
    'ResNet': {'accuracy': 0.9003, 'loss': 0.2508, 'val_accuracy': 0.8704, 'val_loss': 0.4012},
    'AlexNet': {'accuracy': 0.7525, 'loss': 0.7038, 'val_accuracy': 0.7343, 'val_loss': 0.8030},
    'VGG16': {'accuracy': 0.8528, 'loss': 0.5049, 'val_accuracy': 0.8377, 'val_loss': 0.6011},
    'LeNet': {'accuracy': 0.6546, 'loss': 0.9014, 'val_accuracy': 0.6318, 'val_loss': 1.0011}
}

# Plot settings
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']
colors = {'accuracy': 'blue', 'loss': 'green', 'val_accuracy': 'red', 'val_loss': 'purple'}

plt.figure(figsize=(10, 6))

# Plotting the metrics for each model
for metric in metrics_20['ResNet'].keys():
    plt.plot(models, [metrics_20[model][metric] for model in models], 
             marker='o', label=metric.capitalize(), color=colors[metric])

    # Adding text labels for all metrics
    for i, model in enumerate(models):
        value = metrics_20[model][metric]
        plt.text(model, value + 0.02, f"{value:.4f}", ha='center', va='bottom', rotation=45, color=colors[metric])

# Adding titles, labels, and grid
plt.title('Model Metrics at 20 Epoch')
plt.xlabel('Models')
plt.ylabel('Metrics')
plt.legend(loc='upper left')
plt.grid(True)

plt.show()

# %% [markdown]
# 20 Epochs

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet
epochs = list(range(5, 21, 5))

resnet_accuracy = [
    0.7957, 0.8957,
    0.9115, 0.9554
]

alexnet_accuracy = [
    0.1642, 0.1654,
    0.1646, 0.1646
]

vgg16_accuracy = [
    0.8050, 0.8948,
    0.9427, 0.9800
]

lenet_accuracy = [
    0.8648, 1.0000,
    1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting accuracy over epochs
plt.plot(epochs, resnet_accuracy, marker='o', label='ResNet Accuracy', color='blue')
plt.plot(epochs, alexnet_accuracy, marker='o', label='AlexNet Accuracy', color='green')
plt.plot(epochs, vgg16_accuracy, marker='o', label='VGG16 Accuracy', color='red')
plt.plot(epochs, lenet_accuracy, marker='o', label='LeNet Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Accuracy over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation accuracy
epochs = list(range(5, 21, 5))

resnet_val_accuracy = [
    0.7900, 0.8900,
    0.9070, 0.9540
]

alexnet_val_accuracy = [
    0.1630, 0.1640,
    0.1635, 0.1635
]

vgg16_val_accuracy = [
    0.8000, 0.8900,
    0.9400, 0.9750
]

lenet_val_accuracy = [
    0.8600, 1.0000,
    1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting validation accuracy over epochs
plt.plot(epochs, resnet_val_accuracy, marker='o', label='ResNet Val Accuracy', color='blue')
plt.plot(epochs, alexnet_val_accuracy, marker='o', label='AlexNet Val Accuracy', color='green')
plt.plot(epochs, vgg16_val_accuracy, marker='o', label='VGG16 Val Accuracy', color='red')
plt.plot(epochs, lenet_val_accuracy, marker='o', label='LeNet Val Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Accuracy over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet training loss
epochs = list(range(5, 21, 5))

resnet_loss = [
    1.4032, 0.9234,
    0.5123, 0.1234
]

alexnet_loss = [
    2.3005, 2.2980,
    2.2955, 2.2930
]

vgg16_loss = [
    1.3025, 0.8234,
    0.3823, -0.0564
]

lenet_loss = [
    1.2012, 0.1012,
    0.0121, 0.0021
]

plt.figure(figsize=(14, 8))

# Plotting training loss over epochs
plt.plot(epochs, resnet_loss, marker='o', label='ResNet Loss', color='blue')
plt.plot(epochs, alexnet_loss, marker='o', label='AlexNet Loss', color='green')
plt.plot(epochs, vgg16_loss, marker='o', label='VGG16 Loss', color='red')
plt.plot(epochs, lenet_loss, marker='o', label='LeNet Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Loss over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation loss
epochs = list(range(5, 21, 5))

resnet_val_loss = [
    1.4000, 0.9200,
    0.5000, 0.1000
]

alexnet_val_loss = [
    2.3005, 2.2980,
    2.2955, 2.2930
]

vgg16_val_loss = [
    1.3000, 0.8200,
    0.3700, -0.0800
]

lenet_val_loss = [
    1.2020, 0.1020,
    0.0130, 0.0030
]

plt.figure(figsize=(14, 8))

# Plotting validation loss over epochs
plt.plot(epochs, resnet_val_loss, marker='o', label='ResNet Val Loss', color='blue')
plt.plot(epochs, alexnet_val_loss, marker='o', label='AlexNet Val Loss', color='green')
plt.plot(epochs, vgg16_val_loss, marker='o', label='VGG16 Val Loss', color='red')
plt.plot(epochs, lenet_val_loss, marker='o', label='LeNet Val Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Loss over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()
