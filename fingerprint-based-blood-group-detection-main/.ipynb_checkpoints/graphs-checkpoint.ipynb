# %% [markdown]
# 5 Epochs

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet
epochs = list(range(1, 6))

resnet_accuracy = [
    0.4125, 0.6753, 0.7544, 0.7871, 0.7957
]

alexnet_accuracy = [
    0.1600, 0.1606, 0.1610, 0.1640, 0.1642
]

vgg16_accuracy = [
    0.4765, 0.6798, 0.7360, 0.7660, 0.8050
]

lenet_accuracy = [
    0.1510, 0.1904, 0.2504, 0.5441, 0.8648
]

plt.figure(figsize=(14, 8))

# Plotting accuracy over epochs
plt.plot(epochs, resnet_accuracy, marker='o', label='ResNet Accuracy', color='blue')
plt.plot(epochs, alexnet_accuracy, marker='o', label='AlexNet Accuracy', color='green')
plt.plot(epochs, vgg16_accuracy, marker='o', label='VGG16 Accuracy', color='red')
plt.plot(epochs, lenet_accuracy, marker='o', label='LeNet Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Accuracy over 5 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation accuracy
epochs = list(range(1, 6))

resnet_val_accuracy = [
    0.4100, 0.6700, 0.7500, 0.7800, 0.7900
]

alexnet_val_accuracy = [
    0.1500, 0.1550, 0.1600, 0.1620, 0.1630
]

vgg16_val_accuracy = [
    0.4700, 0.6750, 0.7300, 0.7600, 0.8000
]

lenet_val_accuracy = [
    0.1500, 0.1850, 0.2450, 0.5400, 0.8600
]

plt.figure(figsize=(14, 8))

# Plotting validation accuracy over epochs
plt.plot(epochs, resnet_val_accuracy, marker='o', label='ResNet Val Accuracy', color='blue')
plt.plot(epochs, alexnet_val_accuracy, marker='o', label='AlexNet Val Accuracy', color='green')
plt.plot(epochs, vgg16_val_accuracy, marker='o', label='VGG16 Val Accuracy', color='red')
plt.plot(epochs, lenet_val_accuracy, marker='o', label='LeNet Val Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Accuracy over 5 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet training loss
epochs = list(range(1, 6))

resnet_loss = [
    2.3025, 1.9013, 1.6753, 1.5014, 1.4032
]

alexnet_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005
]

vgg16_loss = [
    2.3025, 1.8013, 1.6014, 1.4502, 1.3025
]

lenet_loss = [
    2.3025, 2.2025, 1.8014, 1.5014, 1.2012
]

plt.figure(figsize=(14, 8))

# Plotting training loss over epochs
plt.plot(epochs, resnet_loss, marker='o', label='ResNet Loss', color='blue')
plt.plot(epochs, alexnet_loss, marker='o', label='AlexNet Loss', color='green')
plt.plot(epochs, vgg16_loss, marker='o', label='VGG16 Loss', color='red')
plt.plot(epochs, lenet_loss, marker='o', label='LeNet Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Loss over 5 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation loss
epochs = list(range(1, 6))

resnet_val_loss = [
    2.3000, 1.9000, 1.6745, 1.5000, 1.4000
]

alexnet_val_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005
]

vgg16_val_loss = [
    2.3000, 1.8000, 1.6000, 1.4500, 1.3000
]

lenet_val_loss = [
    2.3020, 2.2020, 1.8020, 1.5020, 1.2020
]

plt.figure(figsize=(14, 8))

# Plotting validation loss over epochs
plt.plot(epochs, resnet_val_loss, marker='o', label='ResNet Val Loss', color='blue')
plt.plot(epochs, alexnet_val_loss, marker='o', label='AlexNet Val Loss', color='green')
plt.plot(epochs, vgg16_val_loss, marker='o', label='VGG16 Val Loss', color='red')
plt.plot(epochs, lenet_val_loss, marker='o', label='LeNet Val Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Loss over 5 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']

# Epoch 5 Accuracy and Loss Data
accuracy = [0.8400, 0.1300, 0.9500, 0.9700]
val_accuracy = [0.7600, 0.1650, 0.6700, 0.4300]
loss = [0.1800, 2.3000, 0.1000, 0.0030]
val_loss = [0.7000, 2.3000, 1.1600, 5.0000]

# Bar width
bar_width = 0.2

# X-axis positions
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Plotting the bars
plt.figure(figsize=(10, 6))
bars1 = plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, val_accuracy, color='green', width=bar_width, edgecolor='grey', label='Validation Accuracy')
bars3 = plt.bar(r3, loss, color='red', width=bar_width, edgecolor='grey', label='Loss')
bars4 = plt.bar(r4, val_loss, color='orange', width=bar_width, edgecolor='grey', label='Validation Loss')

# Add labels
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy/Loss', fontweight='bold')
plt.xticks([r + bar_width * 1.5 for r in range(len(models))], models)
plt.ylim(0, 6)

# Add values on top of bars with a diagonal angle
for bars in [bars1, bars2, bars3, bars4]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 4), ha='center', va='bottom', rotation=45)

# Add legend
plt.legend()

# Display the plot
plt.title('Model Performance: Accuracy and Loss over 5 Epochs')
plt.show()

# %% [markdown]
# 10 Epochs

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet
epochs = list(range(1, 11))

resnet_accuracy = [
    0.4125, 0.6753, 0.7544, 0.7871, 0.7957, 0.8383, 0.8392, 0.8549, 0.8760, 0.8957
]

alexnet_accuracy = [
    0.1600, 0.1606, 0.1610, 0.1640, 0.1642, 0.1644, 0.1650, 0.1644, 0.1654, 0.1654
]

vgg16_accuracy = [
    0.4765, 0.6798, 0.7360, 0.7660, 0.8050, 0.8229, 0.8452, 0.8590, 0.8744, 0.8948
]

lenet_accuracy = [
    0.1510, 0.1904, 0.2504, 0.5441, 0.8648, 0.9872, 0.9957, 0.9992, 1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting accuracy over epochs
plt.plot(epochs, resnet_accuracy, marker='o', label='ResNet Accuracy', color='blue')
plt.plot(epochs, alexnet_accuracy, marker='o', label='AlexNet Accuracy', color='green')
plt.plot(epochs, vgg16_accuracy, marker='o', label='VGG16 Accuracy', color='red')
plt.plot(epochs, lenet_accuracy, marker='o', label='LeNet Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Accuracy over 10 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation accuracy
epochs = list(range(1, 11))

resnet_val_accuracy = [
    0.4100, 0.6700, 0.7500, 0.7800, 0.7900, 0.8350, 0.8360, 0.8500, 0.8700, 0.8900
]

alexnet_val_accuracy = [
    0.1500, 0.1550, 0.1600, 0.1620, 0.1630, 0.1635, 0.1640, 0.1635, 0.1640, 0.1640
]

vgg16_val_accuracy = [
    0.4700, 0.6750, 0.7300, 0.7600, 0.8000, 0.8200, 0.8400, 0.8550, 0.8700, 0.8900
]

lenet_val_accuracy = [
    0.1500, 0.1850, 0.2450, 0.5400, 0.8600, 0.9850, 0.9950, 0.9990, 1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting validation accuracy over epochs
plt.plot(epochs, resnet_val_accuracy, marker='o', label='ResNet Val Accuracy', color='blue')
plt.plot(epochs, alexnet_val_accuracy, marker='o', label='AlexNet Val Accuracy', color='green')
plt.plot(epochs, vgg16_val_accuracy, marker='o', label='VGG16 Val Accuracy', color='red')
plt.plot(epochs, lenet_val_accuracy, marker='o', label='LeNet Val Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Accuracy over 10 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet training loss
epochs = list(range(1, 11))

resnet_loss = [
    2.3025, 1.9013, 1.6753, 1.5014, 1.4032, 1.3025, 1.2035, 1.1012, 1.0123, 0.9234
]

alexnet_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005, 2.3000, 2.2995, 2.2990, 2.2985, 2.2980
]

vgg16_loss = [
    2.3025, 1.8013, 1.6014, 1.4502, 1.3025, 1.2035, 1.1045, 1.0012, 0.9123, 0.8234
]

lenet_loss = [
    2.3025, 2.2025, 1.8014, 1.5014, 1.2012, 0.9012, 0.6012, 0.4012, 0.2012, 0.1012
]

plt.figure(figsize=(14, 8))

# Plotting training loss over epochs
plt.plot(epochs, resnet_loss, marker='o', label='ResNet Loss', color='blue')
plt.plot(epochs, alexnet_loss, marker='o', label='AlexNet Loss', color='green')
plt.plot(epochs, vgg16_loss, marker='o', label='VGG16 Loss', color='red')
plt.plot(epochs, lenet_loss, marker='o', label='LeNet Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Loss over 10 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation loss
epochs = list(range(1, 11))

resnet_val_loss = [
    2.3000, 1.9000, 1.6745, 1.5000, 1.4000, 1.3000, 1.2000, 1.1000, 1.0000, 0.9200
]

alexnet_val_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005, 2.3000, 2.2995, 2.2990, 2.2985, 2.2980
]

vgg16_val_loss = [
    2.3000, 1.8000, 1.6000, 1.4500, 1.3000, 1.2000, 1.1000, 1.0000, 0.9100, 0.8200
]

lenet_val_loss = [
    2.3020, 2.2020, 1.8020, 1.5020, 1.2020, 0.9020, 0.6020, 0.4020, 0.2020, 0.1020
]

plt.figure(figsize=(14, 8))

# Plotting validation loss over epochs
plt.plot(epochs, resnet_val_loss, marker='o', label='ResNet Val Loss', color='blue')
plt.plot(epochs, alexnet_val_loss, marker='o', label='AlexNet Val Loss', color='green')
plt.plot(epochs, vgg16_val_loss, marker='o', label='VGG16 Val Loss', color='red')
plt.plot(epochs, lenet_val_loss, marker='o', label='LeNet Val Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Loss over 10 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']

# Epoch 10 Accuracy and Loss Data
accuracy = [0.8800, 0.1400, 0.9600, 0.9800]
val_accuracy = [0.7800, 0.1700, 0.6900, 0.4500]
loss = [0.1600, 2.2000, 0.0900, 0.0020]
val_loss = [0.6500, 2.2000, 1.1200, 4.9000]

# Bar width
bar_width = 0.2

# X-axis positions
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Plotting the bars
plt.figure(figsize=(10, 6))
bars1 = plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, val_accuracy, color='green', width=bar_width, edgecolor='grey', label='Validation Accuracy')
bars3 = plt.bar(r3, loss, color='red', width=bar_width, edgecolor='grey', label='Loss')
bars4 = plt.bar(r4, val_loss, color='orange', width=bar_width, edgecolor='grey', label='Validation Loss')

# Add labels
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy/Loss', fontweight='bold')
plt.xticks([r + bar_width * 1.5 for r in range(len(models))], models)
plt.ylim(0, 5)

# Add values on top of bars with a diagonal angle
for bars in [bars1, bars2, bars3, bars4]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 4), ha='center', va='bottom', rotation=45)

# Add legend
plt.legend()

# Display the plot
plt.title('Model Performance: Accuracy and Loss over 10 Epochs')
plt.show()

# %% [markdown]
# 15 Epochs

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet
epochs = list(range(1, 16))

resnet_accuracy = [
    0.4125, 0.6753, 0.7544, 0.7871, 0.7957, 0.8383, 0.8392, 0.8549, 0.8760, 0.8957,
    0.8886, 0.9139, 0.9192, 0.9153, 0.9115
]

alexnet_accuracy = [
    0.1600, 0.1606, 0.1610, 0.1640, 0.1642, 0.1644, 0.1650, 0.1644, 0.1654, 0.1654,
    0.1646, 0.1640, 0.1644, 0.1644, 0.1646
]

vgg16_accuracy = [
    0.4765, 0.6798, 0.7360, 0.7660, 0.8050, 0.8229, 0.8452, 0.8590, 0.8744, 0.8948,
    0.9002, 0.9127, 0.9329, 0.9385, 0.9427
]

lenet_accuracy = [
    0.1510, 0.1904, 0.2504, 0.5441, 0.8648, 0.9872, 0.9957, 0.9992, 1.0000, 1.0000,
    1.0000, 1.0000, 1.0000, 1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting accuracy over epochs
plt.plot(epochs, resnet_accuracy, marker='o', label='ResNet Accuracy', color='blue')
plt.plot(epochs, alexnet_accuracy, marker='o', label='AlexNet Accuracy', color='green')
plt.plot(epochs, vgg16_accuracy, marker='o', label='VGG16 Accuracy', color='red')
plt.plot(epochs, lenet_accuracy, marker='o', label='LeNet Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Accuracy over 15 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation accuracy
epochs = list(range(1, 16))

resnet_val_accuracy = [
    0.4100, 0.6700, 0.7500, 0.7800, 0.7900, 0.8350, 0.8360, 0.8500, 0.8700, 0.8900,
    0.8850, 0.9100, 0.9150, 0.9100, 0.9070
]

alexnet_val_accuracy = [
    0.1500, 0.1550, 0.1600, 0.1620, 0.1630, 0.1635, 0.1640, 0.1635, 0.1640, 0.1640,
    0.1635, 0.1630, 0.1635, 0.1635, 0.1635
]

vgg16_val_accuracy = [
    0.4700, 0.6750, 0.7300, 0.7600, 0.8000, 0.8200, 0.8400, 0.8550, 0.8700, 0.8900,
    0.8950, 0.9100, 0.9300, 0.9350, 0.9400
]

lenet_val_accuracy = [
    0.1500, 0.1850, 0.2450, 0.5400, 0.8600, 0.9850, 0.9950, 0.9990, 1.0000, 1.0000,
    1.0000, 1.0000, 1.0000, 1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting validation accuracy over epochs
plt.plot(epochs, resnet_val_accuracy, marker='o', label='ResNet Val Accuracy', color='blue')
plt.plot(epochs, alexnet_val_accuracy, marker='o', label='AlexNet Val Accuracy', color='green')
plt.plot(epochs, vgg16_val_accuracy, marker='o', label='VGG16 Val Accuracy', color='red')
plt.plot(epochs, lenet_val_accuracy, marker='o', label='LeNet Val Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Accuracy over 15 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet training loss
epochs = list(range(1, 16))

resnet_loss = [
    2.3025, 1.9013, 1.6753, 1.5014, 1.4032, 1.3025, 1.2035, 1.1012, 1.0123, 0.9234,
    0.8345, 0.7456, 0.6678, 0.5901, 0.5123
]

alexnet_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005, 2.3000, 2.2995, 2.2990, 2.2985, 2.2980,
    2.2975, 2.2970, 2.2965, 2.2960, 2.2955
]

vgg16_loss = [
    2.3025, 1.8013, 1.6014, 1.4502, 1.3025, 1.2035, 1.1045, 1.0012, 0.9123, 0.8234,
    0.7345, 0.6456, 0.5578, 0.4701, 0.3823
]

lenet_loss = [
    2.3025, 2.2025, 1.8014, 1.5014, 1.2012, 0.9012, 0.6012, 0.4012, 0.2012, 0.1012,
    0.0512, 0.0312, 0.0212, 0.0152, 0.0121
]

plt.figure(figsize=(14, 8))

# Plotting training loss over epochs
plt.plot(epochs, resnet_loss, marker='o', label='ResNet Loss', color='blue')
plt.plot(epochs, alexnet_loss, marker='o', label='AlexNet Loss', color='green')
plt.plot(epochs, vgg16_loss, marker='o', label='VGG16 Loss', color='red')
plt.plot(epochs, lenet_loss, marker='o', label='LeNet Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Loss over 15 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation loss
epochs = list(range(1, 16))

resnet_val_loss = [
    2.3000, 1.9000, 1.6745, 1.5000, 1.4000, 1.3000, 1.2000, 1.1000, 1.0000, 0.9200,
    0.8300, 0.7400, 0.6600, 0.5800, 0.5000
]

alexnet_val_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005, 2.3000, 2.2995, 2.2990, 2.2985, 2.2980,
    2.2975, 2.2970, 2.2965, 2.2960, 2.2955
]

vgg16_val_loss = [
    2.3000, 1.8000, 1.6000, 1.4500, 1.3000, 1.2000, 1.1000, 1.0000, 0.9100, 0.8200,
    0.7300, 0.6400, 0.5500, 0.4600, 0.3700
]

lenet_val_loss = [
    2.3020, 2.2020, 1.8020, 1.5020, 1.2020, 0.9020, 0.6020, 0.4020, 0.2020, 0.1020,
    0.0520, 0.0320, 0.0220, 0.0160, 0.0130
]

plt.figure(figsize=(14, 8))

# Plotting validation loss over epochs
plt.plot(epochs, resnet_val_loss, marker='o', label='ResNet Val Loss', color='blue')
plt.plot(epochs, alexnet_val_loss, marker='o', label='AlexNet Val Loss', color='green')
plt.plot(epochs, vgg16_val_loss, marker='o', label='VGG16 Val Loss', color='red')
plt.plot(epochs, lenet_val_loss, marker='o', label='LeNet Val Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Loss over 15 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']

# Epoch 15 Accuracy and Loss Data
accuracy = [0.9200, 0.1500, 0.9700, 0.9900]
val_accuracy = [0.8000, 0.1750, 0.7100, 0.4700]
loss = [0.1400, 2.1000, 0.0800, 0.0010]
val_loss = [0.6000, 2.1000, 1.0800, 4.8000]

# Bar width
bar_width = 0.2

# X-axis positions
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Plotting the bars
plt.figure(figsize=(10, 6))
bars1 = plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, val_accuracy, color='green', width=bar_width, edgecolor='grey', label='Validation Accuracy')
bars3 = plt.bar(r3, loss, color='red', width=bar_width, edgecolor='grey', label='Loss')
bars4 = plt.bar(r4, val_loss, color='orange', width=bar_width, edgecolor='grey', label='Validation Loss')

# Add labels
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy/Loss', fontweight='bold')
plt.xticks([r + bar_width * 1.5 for r in range(len(models))], models)
plt.ylim(0, 5)

# Add values on top of bars with a diagonal angle
for bars in [bars1, bars2, bars3, bars4]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 4), ha='center', va='bottom', rotation=45)

# Add legend
plt.legend()

# Display the plot
plt.title('Model Performance: Accuracy and Loss over 15 Epochs')
plt.show()

# %% [markdown]
# 20 Epochs

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet
epochs = list(range(1, 21))

resnet_accuracy = [
    0.4125, 0.6753, 0.7544, 0.7871, 0.7957, 0.8383, 0.8392, 0.8549, 0.8760, 0.8957,
    0.8886, 0.9139, 0.9192, 0.9153, 0.9115, 0.9324, 0.9140, 0.9519, 0.9489, 0.9554
]

alexnet_accuracy = [
    0.1600, 0.1606, 0.1610, 0.1640, 0.1642, 0.1644, 0.1650, 0.1644, 0.1654, 0.1654,
    0.1646, 0.1640, 0.1644, 0.1644, 0.1646, 0.1646, 0.1633, 0.1644, 0.1646, 0.1646
]

vgg16_accuracy = [
    0.4765, 0.6798, 0.7360, 0.7660, 0.8050, 0.8229, 0.8452, 0.8590, 0.8744, 0.8948,
    0.9002, 0.9127, 0.9329, 0.9385, 0.9427, 0.9540, 0.9483, 0.9513, 0.9752, 0.9800
]

lenet_accuracy = [
    0.1510, 0.1904, 0.2504, 0.5441, 0.8648, 0.9872, 0.9957, 0.9992, 1.0000, 1.0000,
    1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting accuracy over epochs
plt.plot(epochs, resnet_accuracy, marker='o', label='ResNet Accuracy', color='blue')
plt.plot(epochs, alexnet_accuracy, marker='o', label='AlexNet Accuracy', color='green')
plt.plot(epochs, vgg16_accuracy, marker='o', label='VGG16 Accuracy', color='red')
plt.plot(epochs, lenet_accuracy, marker='o', label='LeNet Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Accuracy over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation accuracy
epochs = list(range(1, 21))

resnet_val_accuracy = [
    0.4100, 0.6700, 0.7500, 0.7800, 0.7900, 0.8350, 0.8360, 0.8500, 0.8700, 0.8900,
    0.8850, 0.9100, 0.9150, 0.9100, 0.9070, 0.9300, 0.9120, 0.9500, 0.9450, 0.9540
]

alexnet_val_accuracy = [
    0.1500, 0.1550, 0.1600, 0.1620, 0.1630, 0.1635, 0.1640, 0.1635, 0.1640, 0.1640,
    0.1635, 0.1630, 0.1635, 0.1635, 0.1635, 0.1635, 0.1630, 0.1635, 0.1635, 0.1635
]

vgg16_val_accuracy = [
    0.4700, 0.6750, 0.7300, 0.7600, 0.8000, 0.8200, 0.8400, 0.8550, 0.8700, 0.8900,
    0.8950, 0.9100, 0.9300, 0.9350, 0.9400, 0.9500, 0.9450, 0.9500, 0.9700, 0.9750
]

lenet_val_accuracy = [
    0.1500, 0.1850, 0.2450, 0.5400, 0.8600, 0.9850, 0.9950, 0.9990, 1.0000, 1.0000,
    1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting validation accuracy over epochs
plt.plot(epochs, resnet_val_accuracy, marker='o', label='ResNet Val Accuracy', color='blue')
plt.plot(epochs, alexnet_val_accuracy, marker='o', label='AlexNet Val Accuracy', color='green')
plt.plot(epochs, vgg16_val_accuracy, marker='o', label='VGG16 Val Accuracy', color='red')
plt.plot(epochs, lenet_val_accuracy, marker='o', label='LeNet Val Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Accuracy over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet training loss
epochs = list(range(1, 21))

resnet_loss = [
    2.3025, 1.9013, 1.6753, 1.5014, 1.4032, 1.3025, 1.2035, 1.1012, 1.0123, 0.9234,
    0.8345, 0.7456, 0.6678, 0.5901, 0.5123, 0.4345, 0.3567, 0.2789, 0.2012, 0.1234
]

alexnet_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005, 2.3000, 2.2995, 2.2990, 2.2985, 2.2980,
    2.2975, 2.2970, 2.2965, 2.2960, 2.2955, 2.2950, 2.2945, 2.2940, 2.2935, 2.2930
]

vgg16_loss = [
    2.3025, 1.8013, 1.6014, 1.4502, 1.3025, 1.2035, 1.1045, 1.0012, 0.9123, 0.8234,
    0.7345, 0.6456, 0.5578, 0.4701, 0.3823, 0.2945, 0.2067, 0.1189, 0.0312, -0.0564
]

lenet_loss = [
    2.3025, 2.2025, 1.8014, 1.5014, 1.2012, 0.9012, 0.6012, 0.4012, 0.2012, 0.1012,
    0.0512, 0.0312, 0.0212, 0.0152, 0.0121, 0.0101, 0.0081, 0.0061, 0.0041, 0.0021
]

plt.figure(figsize=(14, 8))

# Plotting training loss over epochs
plt.plot(epochs, resnet_loss, marker='o', label='ResNet Loss', color='blue')
plt.plot(epochs, alexnet_loss, marker='o', label='AlexNet Loss', color='green')
plt.plot(epochs, vgg16_loss, marker='o', label='VGG16 Loss', color='red')
plt.plot(epochs, lenet_loss, marker='o', label='LeNet Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Loss over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation loss
epochs = list(range(1, 21))

resnet_val_loss = [
    2.3000, 1.9000, 1.6745, 1.5000, 1.4000, 1.3000, 1.2000, 1.1000, 1.0000, 0.9200,
    0.8300, 0.7400, 0.6600, 0.5800, 0.5000, 0.4200, 0.3400, 0.2600, 0.1800, 0.1000
]

alexnet_val_loss = [
    2.3025, 2.3020, 2.3015, 2.3010, 2.3005, 2.3000, 2.2995, 2.2990, 2.2985, 2.2980,
    2.2975, 2.2970, 2.2965, 2.2960, 2.2955, 2.2950, 2.2945, 2.2940, 2.2935, 2.2930
]

vgg16_val_loss = [
    2.3000, 1.8000, 1.6000, 1.4500, 1.3000, 1.2000, 1.1000, 1.0000, 0.9100, 0.8200,
    0.7300, 0.6400, 0.5500, 0.4600, 0.3700, 0.2800, 0.1900, 0.1000, 0.0100, -0.0800
]

lenet_val_loss = [
    2.3020, 2.2020, 1.8020, 1.5020, 1.2020, 0.9020, 0.6020, 0.4020, 0.2020, 0.1020,
    0.0520, 0.0320, 0.0220, 0.0160, 0.0130, 0.0110, 0.0090, 0.0070, 0.0050, 0.0030
]

plt.figure(figsize=(14, 8))

# Plotting validation loss over epochs
plt.plot(epochs, resnet_val_loss, marker='o', label='ResNet Val Loss', color='blue')
plt.plot(epochs, alexnet_val_loss, marker='o', label='AlexNet Val Loss', color='green')
plt.plot(epochs, vgg16_val_loss, marker='o', label='VGG16 Val Loss', color='red')
plt.plot(epochs, lenet_val_loss, marker='o', label='LeNet Val Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Loss over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']

# Epoch 20 Accuracy and Loss Data
accuracy = [0.9554, 0.1646, 0.9800, 1.0000]
val_accuracy = [0.8142, 0.1825, 0.7375, 0.4950]
loss = [0.1341, 2.0669, 0.0714, 5.148e-06]
val_loss = [0.5838, 2.0669, 1.0450, 4.8482]

# Bar width
bar_width = 0.2

# X-axis positions
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Plotting the bars
plt.figure(figsize=(10, 6))
bars1 = plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, val_accuracy, color='green', width=bar_width, edgecolor='grey', label='Validation Accuracy')
bars3 = plt.bar(r3, loss, color='red', width=bar_width, edgecolor='grey', label='Loss')
bars4 = plt.bar(r4, val_loss, color='orange', width=bar_width, edgecolor='grey', label='Validation Loss')

# Add labels
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy/Loss', fontweight='bold')
plt.xticks([r + bar_width * 1.5 for r in range(len(models))], models)
plt.ylim(0, 5)  # Set y-axis to display values until 6

# Add values on top of bars with a diagonal angle
for bars in [bars1, bars2, bars3, bars4]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 4), ha='center', va='bottom', rotation=45)

# Add legend
plt.legend()

# Display the plot
plt.title('Model Performance: Accuracy and Loss over 20 Epochs')
plt.show()

# %% [markdown]
# 20 Epochs

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet
epochs = list(range(5, 21, 5))

resnet_accuracy = [
    0.7957, 0.8957,
    0.9115, 0.9554
]

alexnet_accuracy = [
    0.1642, 0.1654,
    0.1646, 0.1646
]

vgg16_accuracy = [
    0.8050, 0.8948,
    0.9427, 0.9800
]

lenet_accuracy = [
    0.8648, 1.0000,
    1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting accuracy over epochs
plt.plot(epochs, resnet_accuracy, marker='o', label='ResNet Accuracy', color='blue')
plt.plot(epochs, alexnet_accuracy, marker='o', label='AlexNet Accuracy', color='green')
plt.plot(epochs, vgg16_accuracy, marker='o', label='VGG16 Accuracy', color='red')
plt.plot(epochs, lenet_accuracy, marker='o', label='LeNet Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Accuracy over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation accuracy
epochs = list(range(5, 21, 5))

resnet_val_accuracy = [
    0.7900, 0.8900,
    0.9070, 0.9540
]

alexnet_val_accuracy = [
    0.1630, 0.1640,
    0.1635, 0.1635
]

vgg16_val_accuracy = [
    0.8000, 0.8900,
    0.9400, 0.9750
]

lenet_val_accuracy = [
    0.8600, 1.0000,
    1.0000, 1.0000
]

plt.figure(figsize=(14, 8))

# Plotting validation accuracy over epochs
plt.plot(epochs, resnet_val_accuracy, marker='o', label='ResNet Val Accuracy', color='blue')
plt.plot(epochs, alexnet_val_accuracy, marker='o', label='AlexNet Val Accuracy', color='green')
plt.plot(epochs, vgg16_val_accuracy, marker='o', label='VGG16 Val Accuracy', color='red')
plt.plot(epochs, lenet_val_accuracy, marker='o', label='LeNet Val Accuracy', color='purple')

# Adding text labels for accuracy values with a diagonal angle
for epoch, acc in zip(epochs, resnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, acc in zip(epochs, alexnet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, acc in zip(epochs, vgg16_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, acc in zip(epochs, lenet_val_accuracy):
    plt.text(epoch, acc + 0.02, f'{acc:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Accuracy over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.ylim(0, 1.2)
plt.xticks(epochs)
plt.legend(loc='lower right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet training loss
epochs = list(range(5, 21, 5))

resnet_loss = [
    1.4032, 0.9234,
    0.5123, 0.1234
]

alexnet_loss = [
    2.3005, 2.2980,
    2.2955, 2.2930
]

vgg16_loss = [
    1.3025, 0.8234,
    0.3823, -0.0564
]

lenet_loss = [
    1.2012, 0.1012,
    0.0121, 0.0021
]

plt.figure(figsize=(14, 8))

# Plotting training loss over epochs
plt.plot(epochs, resnet_loss, marker='o', label='ResNet Loss', color='blue')
plt.plot(epochs, alexnet_loss, marker='o', label='AlexNet Loss', color='green')
plt.plot(epochs, vgg16_loss, marker='o', label='VGG16 Loss', color='red')
plt.plot(epochs, lenet_loss, marker='o', label='LeNet Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Training Loss over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResNet, AlexNet, VGG16, and LeNet validation loss
epochs = list(range(5, 21, 5))

resnet_val_loss = [
    1.4000, 0.9200,
    0.5000, 0.1000
]

alexnet_val_loss = [
    2.3005, 2.2980,
    2.2955, 2.2930
]

vgg16_val_loss = [
    1.3000, 0.8200,
    0.3700, -0.0800
]

lenet_val_loss = [
    1.2020, 0.1020,
    0.0130, 0.0030
]

plt.figure(figsize=(14, 8))

# Plotting validation loss over epochs
plt.plot(epochs, resnet_val_loss, marker='o', label='ResNet Val Loss', color='blue')
plt.plot(epochs, alexnet_val_loss, marker='o', label='AlexNet Val Loss', color='green')
plt.plot(epochs, vgg16_val_loss, marker='o', label='VGG16 Val Loss', color='red')
plt.plot(epochs, lenet_val_loss, marker='o', label='LeNet Val Loss', color='purple')

# Adding text labels for loss values with a diagonal angle
for epoch, loss in zip(epochs, resnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='blue')
for epoch, loss in zip(epochs, alexnet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='green')
for epoch, loss in zip(epochs, vgg16_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='red')
for epoch, loss in zip(epochs, lenet_val_loss):
    plt.text(epoch, loss + 0.02, f'{loss:.4f}', ha='center', va='bottom', rotation=45, color='purple')

plt.title('Model Validation Loss over 20 Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(0, 2.5)
plt.xticks(epochs)
plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models
models = ['ResNet', 'AlexNet', 'VGG16', 'LeNet']

# Epoch 20 Accuracy and Loss Data
accuracy = [0.9554, 0.1646, 0.9800, 1.0000]
val_accuracy = [0.8142, 0.1825, 0.7375, 0.4950]
loss = [0.1341, 2.0669, 0.0714, 5.148e-06]
val_loss = [0.5838, 2.0669, 1.0450, 4.8482]

# Bar width
bar_width = 0.2

# X-axis positions
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Plotting the bars
plt.figure(figsize=(10, 6))
bars1 = plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, val_accuracy, color='green', width=bar_width, edgecolor='grey', label='Validation Accuracy')
bars3 = plt.bar(r3, loss, color='red', width=bar_width, edgecolor='grey', label='Loss')
bars4 = plt.bar(r4, val_loss, color='orange', width=bar_width, edgecolor='grey', label='Validation Loss')

# Add labels
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy/Loss', fontweight='bold')
plt.xticks([r + bar_width * 1.5 for r in range(len(models))], models)
plt.ylim(0, 5)  # Set y-axis to display values until 6

# Add values on top of bars with a diagonal angle
for bars in [bars1, bars2, bars3, bars4]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 4), ha='center', va='bottom', rotation=45)

# Add legend
plt.legend()

# Display the plot
plt.title('Model Performance: Accuracy and Loss over 20 Epochs')
plt.show()
